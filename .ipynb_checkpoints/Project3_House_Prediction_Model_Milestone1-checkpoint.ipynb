# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#Loading data

data = pd.read_csv("AmesHousing.csv")
data
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 3      NaN       Reg          Lvl    AllPub     Corner        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2925   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926   NaN       IR1          Low    AllPub     Inside        Mod
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2929   NaN       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0           NAmes        Norm        Norm      1Fam      1Story             6
# 1           NAmes       Feedr        Norm      1Fam      1Story             5
# 2           NAmes        Norm        Norm      1Fam      1Story             6
# 3           NAmes        Norm        Norm      1Fam      1Story             7
# 4         Gilbert        Norm        Norm      1Fam      2Story             5
# ...           ...         ...         ...       ...         ...           ...
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                5        1960            1960        Hip   CompShg
# 1                6        1961            1961      Gable   CompShg
# 2                6        1958            1958        Hip   CompShg
# 3                5        1968            1968        Hip   CompShg
# 4                5        1997            1998      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         BrkFace      Plywood        Stone         112.0         TA
# 1         VinylSd      VinylSd          NaN           0.0         TA
# 2         Wd Sdng      Wd Sdng      BrkFace         108.0         TA
# 3         BrkFace      BrkFace          NaN           0.0         Gd
# 4         VinylSd      VinylSd          NaN           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2925      HdBoard      HdBoard          NaN           0.0         TA
# 2926      HdBoard      HdBoard          NaN           0.0         TA
# 2927      HdBoard      Wd Shng          NaN           0.0         TA
# 2928      HdBoard      HdBoard          NaN           0.0         TA
# 2929      HdBoard      HdBoard      BrkFace          94.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        Gd            Gd            BLQ
# 1            TA     CBlock        TA        TA            No            Rec
# 2            TA     CBlock        TA        TA            No            ALQ
# 3            TA     CBlock        TA        TA            No            ALQ
# 4            TA      PConc        Gd        TA            No            GLQ
# ...         ...        ...       ...       ...           ...            ...
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0            639.0            Unf           0.0        441.0         1080.0
# 1            468.0            LwQ         144.0        270.0          882.0
# 2            923.0            Unf           0.0        406.0         1329.0
# 3           1065.0            Unf           0.0       1045.0         2110.0
# 4            791.0            Unf           0.0        137.0          928.0
# ...            ...            ...           ...          ...            ...
# 2925         819.0            Unf           0.0        184.0         1003.0
# 2926         301.0            ALQ         324.0        239.0          864.0
# 2927         337.0            Unf           0.0        575.0          912.0
# 2928        1071.0            LwQ         123.0        195.0         1389.0
# 2929         758.0            Unf           0.0        238.0          996.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Fa           Y      SBrkr        1656           0
# 1       GasA         TA           Y      SBrkr         896           0
# 2       GasA         TA           Y      SBrkr        1329           0
# 3       GasA         Ex           Y      SBrkr        2110           0
# 4       GasA         Gd           Y      SBrkr         928         701
# ...      ...        ...         ...        ...         ...         ...
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                   0         1656             1.0             0.0          1
# 1                   0          896             0.0             0.0          1
# 2                   0         1329             0.0             0.0          1
# 3                   0         2110             1.0             0.0          2
# 4                   0         1629             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2925                0         1003             1.0             0.0          1
# 2926                0          902             1.0             0.0          1
# 2927                0          970             0.0             1.0          1
# 2928                0         1389             1.0             0.0          1
# 2929                0         2000             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0             0              3              1           TA              7
# 1             0              2              1           TA              5
# 2             1              3              1           Gd              6
# 3             1              3              1           Ex              8
# 4             1              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           2           Gd      Attchd         1960.0
# 1           Typ           0          NaN      Attchd         1961.0
# 2           Typ           0          NaN      Attchd         1958.0
# 3           Typ           2           TA      Attchd         1968.0
# 4           Typ           1           TA      Attchd         1997.0
# ...         ...         ...          ...         ...            ...
# 2925        Typ           0          NaN      Detchd         1984.0
# 2926        Typ           0          NaN      Attchd         1983.0
# 2927        Typ           0          NaN         NaN            NaN
# 2928        Typ           1           TA      Attchd         1975.0
# 2929        Typ           1           TA      Attchd         1993.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0              Fin          2.0        528.0          TA          TA
# 1              Unf          1.0        730.0          TA          TA
# 2              Unf          1.0        312.0          TA          TA
# 3              Fin          2.0        522.0          TA          TA
# 4              Fin          2.0        482.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2925           Unf          2.0        588.0          TA          TA
# 2926           Unf          2.0        484.0          TA          TA
# 2927           NaN          0.0          0.0         NaN         NaN
# 2928           RFn          2.0        418.0          TA          TA
# 2929           Fin          3.0        650.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0              P           210             62               0           0
# 1              Y           140              0               0           0
# 2              Y           393             36               0           0
# 3              Y             0              0               0           0
# 4              Y           212             34               0           0
# ...          ...           ...            ...             ...         ...
# 2925           Y           120              0               0           0
# 2926           Y           164              0               0           0
# 2927           Y            80             32               0           0
# 2928           Y           240             38               0           0
# 2929           Y           190             48               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0     NaN    NaN          NaN         0        5
# 1              120          0     NaN  MnPrv          NaN         0        6
# 2                0          0     NaN    NaN         Gar2     12500        6
# 3                0          0     NaN    NaN          NaN         0        4
# 4                0          0     NaN  MnPrv          NaN         0        3
# ...            ...        ...     ...    ...          ...       ...      ...
# 2925             0          0     NaN  GdPrv          NaN         0        3
# 2926             0          0     NaN  MnPrv          NaN         0        6
# 2927             0          0     NaN  MnPrv         Shed       700        7
# 2928             0          0     NaN    NaN          NaN         0        4
# 2929             0          0     NaN    NaN          NaN         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2010       WD          Normal     215000
# 1        2010       WD          Normal     105000
# 2        2010       WD          Normal     172000
# 3        2010       WD          Normal     244000
# 4        2010       WD          Normal     189900
# ...       ...       ...            ...        ...
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000
#
# [2930 rows x 82 columns]

# %%
#Checking for missing values in each column
missing_values = data.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
print("\nMissing Values:\n", missing_values)
# Out:
# Missing Values:
#  Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Mas Vnr Type      1775
# Fireplace Qu      1422
# Lot Frontage       490
# Garage Qual        159
# Garage Cond        159
# Garage Yr Blt      159
# Garage Finish      159
# Garage Type        157
# Bsmt Exposure       83
# BsmtFin Type 2      81
# Bsmt Cond           80
# Bsmt Qual           80
# BsmtFin Type 1      80
# Mas Vnr Area        23
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# BsmtFin SF 1         1
# BsmtFin SF 2         1
# Electrical           1
# Total Bsmt SF        1
# Bsmt Unf SF          1
# Garage Area          1
# Garage Cars          1
# dtype: int64

# %%
#Handling missing values for needed columns

data['Lot Frontage'] = data['Lot Frontage'].fillna(data['Lot Frontage'].median())
data['Mas Vnr Area'] = data['Mas Vnr Area'].fillna(0)
data['Bsmt Full Bath'] = data['Bsmt Full Bath'].fillna(0)
data['Bsmt Half Bath'] = data['Bsmt Half Bath'].fillna(0)
data['BsmtFin SF 1'] = data['BsmtFin SF 1'].fillna(0)
data['BsmtFin SF 2'] = data['BsmtFin SF 2'].fillna(0)
data['Total Bsmt SF'] = data['Total Bsmt SF'].fillna(0)
data['Bsmt Unf SF'] = data['Bsmt Unf SF'].fillna(0)
data['Garage Cars'] = data['Garage Cars'].fillna(0)
data['Garage Area'] = data['Garage Area'].fillna(0)

# %%
#Outliers
#Define a function to detect outliers using the IQR method

def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return len(outliers)

# Focus on key numerical features relevant to house prices
numerical_features = ['SalePrice', 'Lot Area', 'Lot Frontage', 'Gr Liv Area', 'Total Bsmt SF', 'Mas Vnr Area']
for feature in numerical_features:
    print(f"Outliers in {feature}: {detect_outliers(data, feature)}")
# Out:
# Outliers in SalePrice: 137
# Outliers in Lot Area: 127
# Outliers in Lot Frontage: 261
# Outliers in Gr Liv Area: 75
# Outliers in Total Bsmt SF: 124
# Outliers in Mas Vnr Area: 0

# %%
#Visualize outliers using boxplot
plt.figure(figsize=(15, 12))
for i, feature in enumerate(numerical_features):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(x=data[feature])
    plt.title(f'Boxplot of {feature}')
    plt.tight_layout()

# %%
#Handle outliers
data['SalePrice'] = data['SalePrice'].clip(upper=data['SalePrice'].quantile(0.95))
data['Gr Liv Area'] = data['Gr Liv Area'].clip(upper=data['Gr Liv Area'].quantile(0.95))
data['Lot Area'] = data['Lot Area'].clip(upper=data['Lot Area'].quantile(0.95))
data['Total Bsmt SF'] = data['Total Bsmt SF'].clip(upper=data['Total Bsmt SF'].quantile(0.95))
data['Total Bsmt SF'] = data['Total Bsmt SF'].clip(lower=data['Total Bsmt SF'].quantile(0.05))

# %%
#Data inconsistencies
# Verify categorical columns for invalid entries
categorical_cols = data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values in {col}:\n", data[col].value_counts())

# Check numerical columns for negative or invalid values
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_cols:
    if (data[col] < 0).any():
        print(f"\nNegative values found in {col}:\n", data[data[col] < 0][col])
# Out:
# Unique values in MS Zoning:
#  MS Zoning
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# I (all)       2
# A (agr)       2
# Name: count, dtype: int64
#
# Unique values in Street:
#  Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64
#
# Unique values in Alley:
#  Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64
#
# Unique values in Lot Shape:
#  Lot Shape
# Reg    1859
# IR1     979
# IR2      76
# IR3      16
# Name: count, dtype: int64
#
# Unique values in Land Contour:
#  Land Contour
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: count, dtype: int64
#
# Unique values in Utilities:
#  Utilities
# AllPub    2927
# NoSewr       2
# NoSeWa       1
# Name: count, dtype: int64
#
# Unique values in Lot Config:
#  Lot Config
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# FR3          14
# Name: count, dtype: int64
#
# Unique values in Land Slope:
#  Land Slope
# Gtl    2789
# Mod     125
# Sev      16
# Name: count, dtype: int64
#
# Unique values in Neighborhood:
#  Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: count, dtype: int64
#
# Unique values in Condition 1:
#  Condition 1
# Norm      2522
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: count, dtype: int64
#
# Unique values in Condition 2:
#  Condition 2
# Norm      2900
# Feedr       13
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAe         1
# RRAn         1
# Name: count, dtype: int64
#
# Unique values in Bldg Type:
#  Bldg Type
# 1Fam      2425
# TwnhsE     233
# Duplex     109
# Twnhs      101
# 2fmCon      62
# Name: count, dtype: int64
#
# Unique values in House Style:
#  House Style
# 1Story    1481
# 2Story     873
# 1.5Fin     314
# SLvl       128
# SFoyer      83
# 2.5Unf      24
# 1.5Unf      19
# 2.5Fin       8
# Name: count, dtype: int64
#
# Unique values in Roof Style:
#  Roof Style
# Gable      2321
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: count, dtype: int64
#
# Unique values in Roof Matl:
#  Roof Matl
# CompShg    2887
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Membran       1
# ClyTile       1
# Roll          1
# Metal         1
# Name: count, dtype: int64
#
# Unique values in Exterior 1st:
#  Exterior 1st
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# CBlock        2
# Stone         2
# PreCast       1
# ImStucc       1
# Name: count, dtype: int64
#
# Unique values in Exterior 2nd:
#  Exterior 2nd
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     397
# Plywood     274
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# PreCast       1
# Other         1
# Name: count, dtype: int64
#
# Unique values in Mas Vnr Type:
#  Mas Vnr Type
# BrkFace    880
# Stone      249
# BrkCmn      25
# CBlock       1
# Name: count, dtype: int64
#
# Unique values in Exter Qual:
#  Exter Qual
# TA    1799
# Gd     989
# Ex     107
# Fa      35
# Name: count, dtype: int64
#
# Unique values in Exter Cond:
#  Exter Cond
# TA    2549
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: count, dtype: int64
#
# Unique values in Foundation:
#  Foundation
# PConc     1310
# CBlock    1244
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: count, dtype: int64
#
# Unique values in Bsmt Qual:
#  Bsmt Qual
# TA    1283
# Gd    1219
# Ex     258
# Fa      88
# Po       2
# Name: count, dtype: int64
#
# Unique values in Bsmt Cond:
#  Bsmt Cond
# TA    2616
# Gd     122
# Fa     104
# Po       5
# Ex       3
# Name: count, dtype: int64
#
# Unique values in Bsmt Exposure:
#  Bsmt Exposure
# No    1906
# Av     418
# Gd     284
# Mn     239
# Name: count, dtype: int64
#
# Unique values in BsmtFin Type 1:
#  BsmtFin Type 1
# GLQ    859
# Unf    851
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: count, dtype: int64
#
# Unique values in BsmtFin Type 2:
#  BsmtFin Type 2
# Unf    2499
# Rec     106
# LwQ      89
# BLQ      68
# ALQ      53
# GLQ      34
# Name: count, dtype: int64
#
# Unique values in Heating:
#  Heating
# GasA     2885
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: count, dtype: int64
#
# Unique values in Heating QC:
#  Heating QC
# Ex    1495
# TA     864
# Gd     476
# Fa      92
# Po       3
# Name: count, dtype: int64
#
# Unique values in Central Air:
#  Central Air
# Y    2734
# N     196
# Name: count, dtype: int64
#
# Unique values in Electrical:
#  Electrical
# SBrkr    2682
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64
#
# Unique values in Kitchen Qual:
#  Kitchen Qual
# TA    1494
# Gd    1160
# Ex     205
# Fa      70
# Po       1
# Name: count, dtype: int64
#
# Unique values in Functional:
#  Functional
# Typ     2728
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Sal        2
# Name: count, dtype: int64
#
# Unique values in Fireplace Qu:
#  Fireplace Qu
# Gd    744
# TA    600
# Fa     75
# Po     46
# Ex     43
# Name: count, dtype: int64
#
# Unique values in Garage Type:
#  Garage Type
# Attchd     1731
# Detchd      782
# BuiltIn     186
# Basment      36
# 2Types       23
# CarPort      15
# Name: count, dtype: int64
#
# Unique values in Garage Finish:
#  Garage Finish
# Unf    1231
# RFn     812
# Fin     728
# Name: count, dtype: int64
#
# Unique values in Garage Qual:
#  Garage Qual
# TA    2615
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: count, dtype: int64
#
# Unique values in Garage Cond:
#  Garage Cond
# TA    2665
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: count, dtype: int64
#
# Unique values in Paved Drive:
#  Paved Drive
# Y    2652
# N     216
# P      62
# Name: count, dtype: int64
#
# Unique values in Pool QC:
#  Pool QC
# Ex    4
# Gd    4
# TA    3
# Fa    2
# Name: count, dtype: int64
#
# Unique values in Fence:
#  Fence
# MnPrv    330
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64
#
# Unique values in Misc Feature:
#  Misc Feature
# Shed    95
# Gar2     5
# Othr     4
# Elev     1
# TenC     1
# Name: count, dtype: int64
#
# Unique values in Sale Type:
#  Sale Type
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: count, dtype: int64
#
# Unique values in Sale Condition:
#  Sale Condition
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: count, dtype: int64

# %%
#Feature Engineering

#Selecting relevant features 
selected_features = [
    'Neighborhood', 'MS Zoning', 'Lot Frontage', 'Lot Area',  # Location
    'Gr Liv Area', 'Total Bsmt SF',  # Square footage
    'Bedroom AbvGr',  # Number of bedrooms
    'Yr Sold', 'Mo Sold', 'Sale Condition',  # Market conditions
    'Overall Qual', 'Year Built', 'Full Bath', 'Half Bath',  # Additional high-impact features
    'SalePrice'  # Target variable (kept for correlation analysis)
]
data_selected = data[selected_features]
data_selected
# Out:
#      Neighborhood MS Zoning  Lot Frontage  Lot Area  Gr Liv Area  \
# 0           NAmes        RL         141.0  17126.05       1656.0
# 1           NAmes        RH          80.0  11622.00        896.0
# 2           NAmes        RL          81.0  14267.00       1329.0
# 3           NAmes        RL          93.0  11160.00       2110.0
# 4         Gilbert        RL          74.0  13830.00       1629.0
# ...           ...       ...           ...       ...          ...
# 2925      Mitchel        RL          37.0   7937.00       1003.0
# 2926      Mitchel        RL          68.0   8885.00        902.0
# 2927      Mitchel        RL          62.0  10441.00        970.0
# 2928      Mitchel        RL          77.0  10010.00       1389.0
# 2929      Mitchel        RL          74.0   9627.00       2000.0
#
#       Total Bsmt SF  Bedroom AbvGr  Yr Sold  Mo Sold Sale Condition  \
# 0            1080.0              3     2010        5         Normal
# 1             882.0              2     2010        6         Normal
# 2            1329.0              3     2010        6         Normal
# 3            1776.0              3     2010        4         Normal
# 4             928.0              3     2010        3         Normal
# ...             ...            ...      ...      ...            ...
# 2925         1003.0              3     2006        3         Normal
# 2926          864.0              2     2006        6         Normal
# 2927          912.0              3     2006        7         Normal
# 2928         1389.0              2     2006        4         Normal
# 2929          996.0              3     2006       11         Normal
#
#       Overall Qual  Year Built  Full Bath  Half Bath  SalePrice
# 0                6        1960          1          0     215000
# 1                5        1961          1          0     105000
# 2                6        1958          1          1     172000
# 3                7        1968          2          1     244000
# 4                5        1997          2          1     189900
# ...            ...         ...        ...        ...        ...
# 2925             6        1984          1          0     142500
# 2926             5        1983          1          0     131000
# 2927             5        1992          1          0     132000
# 2928             5        1974          1          0     170000
# 2929             7        1993          2          1     188000
#
# [2930 rows x 15 columns]

# %%
#Creating new features

data_selected.loc[:, 'Total_SF'] = data_selected['Gr Liv Area'] + data_selected['Total Bsmt SF']  # Total square footage
data_selected.loc[:, 'House_Age'] = data_selected['Yr Sold'] - data_selected['Year Built']        # House age
data_selected.loc[:, 'Total_Bath'] = data_selected['Full Bath'] + 0.5 * data_selected['Half Bath']  # Total bathrooms
data_selected.loc[:, 'Neighborhood_Qual'] = data_selected['Neighborhood'] + '_' + data_selected['Overall Qual'].astype(str)  # Neighborhood & quality

# %%
data_selected
# Out:
#      Neighborhood MS Zoning  Lot Frontage  Lot Area  Gr Liv Area  \
# 0           NAmes        RL         141.0  17126.05       1656.0
# 1           NAmes        RH          80.0  11622.00        896.0
# 2           NAmes        RL          81.0  14267.00       1329.0
# 3           NAmes        RL          93.0  11160.00       2110.0
# 4         Gilbert        RL          74.0  13830.00       1629.0
# ...           ...       ...           ...       ...          ...
# 2925      Mitchel        RL          37.0   7937.00       1003.0
# 2926      Mitchel        RL          68.0   8885.00        902.0
# 2927      Mitchel        RL          62.0  10441.00        970.0
# 2928      Mitchel        RL          77.0  10010.00       1389.0
# 2929      Mitchel        RL          74.0   9627.00       2000.0
#
#       Total Bsmt SF  Bedroom AbvGr  Yr Sold  Mo Sold Sale Condition  \
# 0            1080.0              3     2010        5         Normal
# 1             882.0              2     2010        6         Normal
# 2            1329.0              3     2010        6         Normal
# 3            1776.0              3     2010        4         Normal
# 4             928.0              3     2010        3         Normal
# ...             ...            ...      ...      ...            ...
# 2925         1003.0              3     2006        3         Normal
# 2926          864.0              2     2006        6         Normal
# 2927          912.0              3     2006        7         Normal
# 2928         1389.0              2     2006        4         Normal
# 2929          996.0              3     2006       11         Normal
#
#       Overall Qual  Year Built  Full Bath  Half Bath  SalePrice  Total_SF  \
# 0                6        1960          1          0     215000    2736.0
# 1                5        1961          1          0     105000    1778.0
# 2                6        1958          1          1     172000    2658.0
# 3                7        1968          2          1     244000    3886.0
# 4                5        1997          2          1     189900    2557.0
# ...            ...         ...        ...        ...        ...       ...
# 2925             6        1984          1          0     142500    2006.0
# 2926             5        1983          1          0     131000    1766.0
# 2927             5        1992          1          0     132000    1882.0
# 2928             5        1974          1          0     170000    2778.0
# 2929             7        1993          2          1     188000    2996.0
#
#       House_Age  Total_Bath Neighborhood_Qual
# 0            50         1.0           NAmes_6
# 1            49         1.0           NAmes_5
# 2            52         1.5           NAmes_6
# 3            42         2.5           NAmes_7
# 4            13         2.5         Gilbert_5
# ...         ...         ...               ...
# 2925         22         1.0         Mitchel_6
# 2926         23         1.0         Mitchel_5
# 2927         14         1.0         Mitchel_5
# 2928         32         1.0         Mitchel_5
# 2929         13         2.5         Mitchel_7
#
# [2930 rows x 19 columns]

# %%
#Encode Categorical Features
categorical_cols = ['MS Zoning', 'Sale Condition', 'Neighborhood_Qual']
data_encoded = pd.get_dummies(data_selected, columns=categorical_cols, drop_first=True)

# Encode Overall Qual as ordinal (since it’s ordered: 1 to 10)
label_encoder = LabelEncoder()
data_encoded['Overall Qual'] = label_encoder.fit_transform(data_selected['Overall Qual'])

# %%
#Feature selection using correlation analysis
corr_matrix = data_encoded.select_dtypes(include=['int64', 'float64']).corr()
print("\nCorrelation with SalePrice:\n", corr_matrix['SalePrice'].sort_values(ascending=False))
# Out:
# Correlation with SalePrice:
#  SalePrice         1.000000
# Overall Qual      0.821974
# Total_SF          0.820744
# Gr Liv Area       0.726398
# Total Bsmt SF     0.637848
# Total_Bath        0.611859
# Year Built        0.604045
# Full Bath         0.577248
# Lot Area          0.412682
# Lot Frontage      0.337101
# Half Bath         0.295098
# Bedroom AbvGr     0.155474
# Mo Sold           0.045887
# Yr Sold          -0.028978
# Lot_Size_Ratio   -0.186350
# House_Age        -0.604387
# Name: SalePrice, dtype: float64

# %%
# Visualize correlation matrix for top features
top_features = corr_matrix['SalePrice'].abs().sort_values(ascending=False).index
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix.loc[top_features, top_features], annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Top Features with SalePrice')
plt.show()

# %%
data_encoded
# Out:
#      Neighborhood  Lot Frontage  Lot Area  Gr Liv Area  Total Bsmt SF  \
# 0           NAmes         141.0  17126.05       1656.0         1080.0
# 1           NAmes          80.0  11622.00        896.0          882.0
# 2           NAmes          81.0  14267.00       1329.0         1329.0
# 3           NAmes          93.0  11160.00       2110.0         1776.0
# 4         Gilbert          74.0  13830.00       1629.0          928.0
# ...           ...           ...       ...          ...            ...
# 2925      Mitchel          37.0   7937.00       1003.0         1003.0
# 2926      Mitchel          68.0   8885.00        902.0          864.0
# 2927      Mitchel          62.0  10441.00        970.0          912.0
# 2928      Mitchel          77.0  10010.00       1389.0         1389.0
# 2929      Mitchel          74.0   9627.00       2000.0          996.0
#
#       Bedroom AbvGr  Overall Qual  Year Built  Full Bath  Half Bath  \
# 0                 3             5        1960          1          0
# 1                 2             4        1961          1          0
# 2                 3             5        1958          1          1
# 3                 3             6        1968          2          1
# 4                 3             4        1997          2          1
# ...             ...           ...         ...        ...        ...
# 2925              3             5        1984          1          0
# 2926              2             4        1983          1          0
# 2927              3             4        1992          1          0
# 2928              2             4        1974          1          0
# 2929              3             6        1993          2          1
#
#       SalePrice  Total_SF  House_Age  Total_Bath  MS Zoning_C (all)  \
# 0        215000    2736.0         50         1.0              False
# 1        105000    1778.0         49         1.0              False
# 2        172000    2658.0         52         1.5              False
# 3        244000    3886.0         42         2.5              False
# 4        189900    2557.0         13         2.5              False
# ...         ...       ...        ...         ...                ...
# 2925     142500    2006.0         22         1.0              False
# 2926     131000    1766.0         23         1.0              False
# 2927     132000    1882.0         14         1.0              False
# 2928     170000    2778.0         32         1.0              False
# 2929     188000    2996.0         13         2.5              False
#
#       MS Zoning_FV  MS Zoning_I (all)  MS Zoning_RH  MS Zoning_RL  \
# 0            False              False         False          True
# 1            False              False          True         False
# 2            False              False         False          True
# 3            False              False         False          True
# 4            False              False         False          True
# ...            ...                ...           ...           ...
# 2925         False              False         False          True
# 2926         False              False         False          True
# 2927         False              False         False          True
# 2928         False              False         False          True
# 2929         False              False         False          True
#
#       MS Zoning_RM  Sale Condition_AdjLand  Sale Condition_Alloca  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
# ...            ...                     ...                    ...
# 2925         False                   False                  False
# 2926         False                   False                  False
# 2927         False                   False                  False
# 2928         False                   False                  False
# 2929         False                   False                  False
#
#       Sale Condition_Family  Sale Condition_Normal  Sale Condition_Partial  \
# 0                     False                   True                   False
# 1                     False                   True                   False
# 2                     False                   True                   False
# 3                     False                   True                   False
# 4                     False                   True                   False
# ...                     ...                    ...                     ...
# 2925                  False                   True                   False
# 2926                  False                   True                   False
# 2927                  False                   True                   False
# 2928                  False                   True                   False
# 2929                  False                   True                   False
#
#       Neighborhood_Qual_Blmngtn_8  Neighborhood_Qual_Blueste_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Blueste_8  Neighborhood_Qual_BrDale_5  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_BrDale_6  Neighborhood_Qual_BrkSide_1  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ...                          ...                          ...
# 2925                       False                        False
# 2926                       False                        False
# 2927                       False                        False
# 2928                       False                        False
# 2929                       False                        False
#
#       Neighborhood_Qual_BrkSide_2  Neighborhood_Qual_BrkSide_3  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_BrkSide_4  Neighborhood_Qual_BrkSide_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_BrkSide_6  Neighborhood_Qual_BrkSide_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_ClearCr_4  Neighborhood_Qual_ClearCr_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_ClearCr_6  Neighborhood_Qual_ClearCr_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_ClearCr_8  Neighborhood_Qual_CollgCr_4  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_CollgCr_5  Neighborhood_Qual_CollgCr_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_CollgCr_7  Neighborhood_Qual_CollgCr_8  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_CollgCr_9  Neighborhood_Qual_Crawfor_4  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Crawfor_5  Neighborhood_Qual_Crawfor_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Crawfor_7  Neighborhood_Qual_Crawfor_8  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Edwards_1  Neighborhood_Qual_Edwards_10  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# ...                           ...                           ...
# 2925                        False                         False
# 2926                        False                         False
# 2927                        False                         False
# 2928                        False                         False
# 2929                        False                         False
#
#       Neighborhood_Qual_Edwards_2  Neighborhood_Qual_Edwards_3  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Edwards_4  Neighborhood_Qual_Edwards_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Edwards_6  Neighborhood_Qual_Edwards_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Edwards_9  Neighborhood_Qual_Gilbert_4  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Gilbert_5  Neighborhood_Qual_Gilbert_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                            True                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Gilbert_7  Neighborhood_Qual_Gilbert_8  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Gilbert_9  Neighborhood_Qual_Greens_8  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_GrnHill_7  Neighborhood_Qual_IDOTRR_1  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_IDOTRR_2  Neighborhood_Qual_IDOTRR_3  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_IDOTRR_4  Neighborhood_Qual_IDOTRR_5  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_IDOTRR_6  Neighborhood_Qual_IDOTRR_7  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_Landmrk_6  Neighborhood_Qual_MeadowV_4  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_MeadowV_5  Neighborhood_Qual_MeadowV_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Mitchel_1  Neighborhood_Qual_Mitchel_3  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Mitchel_4  Neighborhood_Qual_Mitchel_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                         True
# 2927                        False                         True
# 2928                        False                         True
# 2929                        False                        False
#
#       Neighborhood_Qual_Mitchel_6  Neighborhood_Qual_Mitchel_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                         True                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                         True
#
#       Neighborhood_Qual_Mitchel_8  Neighborhood_Qual_NAmes_3  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ...                           ...                        ...
# 2925                        False                      False
# 2926                        False                      False
# 2927                        False                      False
# 2928                        False                      False
# 2929                        False                      False
#
#       Neighborhood_Qual_NAmes_4  Neighborhood_Qual_NAmes_5  \
# 0                         False                      False
# 1                         False                       True
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 2925                      False                      False
# 2926                      False                      False
# 2927                      False                      False
# 2928                      False                      False
# 2929                      False                      False
#
#       Neighborhood_Qual_NAmes_6  Neighborhood_Qual_NAmes_7  \
# 0                          True                      False
# 1                         False                      False
# 2                          True                      False
# 3                         False                       True
# 4                         False                      False
# ...                         ...                        ...
# 2925                      False                      False
# 2926                      False                      False
# 2927                      False                      False
# 2928                      False                      False
# 2929                      False                      False
#
#       Neighborhood_Qual_NAmes_8  Neighborhood_Qual_NPkVill_6  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                         False                        False
# 4                         False                        False
# ...                         ...                          ...
# 2925                      False                        False
# 2926                      False                        False
# 2927                      False                        False
# 2928                      False                        False
# 2929                      False                        False
#
#       Neighborhood_Qual_NPkVill_7  Neighborhood_Qual_NWAmes_5  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_NWAmes_6  Neighborhood_Qual_NWAmes_7  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_NWAmes_8  Neighborhood_Qual_NoRidge_10  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 2925                       False                         False
# 2926                       False                         False
# 2927                       False                         False
# 2928                       False                         False
# 2929                       False                         False
#
#       Neighborhood_Qual_NoRidge_6  Neighborhood_Qual_NoRidge_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_NoRidge_8  Neighborhood_Qual_NoRidge_9  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_NridgHt_10  Neighborhood_Qual_NridgHt_6  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ...                            ...                          ...
# 2925                         False                        False
# 2926                         False                        False
# 2927                         False                        False
# 2928                         False                        False
# 2929                         False                        False
#
#       Neighborhood_Qual_NridgHt_7  Neighborhood_Qual_NridgHt_8  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_NridgHt_9  Neighborhood_Qual_OldTown_10  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# ...                           ...                           ...
# 2925                        False                         False
# 2926                        False                         False
# 2927                        False                         False
# 2928                        False                         False
# 2929                        False                         False
#
#       Neighborhood_Qual_OldTown_2  Neighborhood_Qual_OldTown_3  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_OldTown_4  Neighborhood_Qual_OldTown_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_OldTown_6  Neighborhood_Qual_OldTown_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_OldTown_8  Neighborhood_Qual_SWISU_2  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ...                           ...                        ...
# 2925                        False                      False
# 2926                        False                      False
# 2927                        False                      False
# 2928                        False                      False
# 2929                        False                      False
#
#       Neighborhood_Qual_SWISU_4  Neighborhood_Qual_SWISU_5  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 2925                      False                      False
# 2926                      False                      False
# 2927                      False                      False
# 2928                      False                      False
# 2929                      False                      False
#
#       Neighborhood_Qual_SWISU_6  Neighborhood_Qual_SWISU_7  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 2925                      False                      False
# 2926                      False                      False
# 2927                      False                      False
# 2928                      False                      False
# 2929                      False                      False
#
#       Neighborhood_Qual_SawyerW_4  Neighborhood_Qual_SawyerW_5  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_SawyerW_6  Neighborhood_Qual_SawyerW_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_SawyerW_8  Neighborhood_Qual_Sawyer_2  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_Sawyer_4  Neighborhood_Qual_Sawyer_5  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_Sawyer_6  Neighborhood_Qual_Sawyer_7  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_Somerst_10  Neighborhood_Qual_Somerst_5  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ...                            ...                          ...
# 2925                         False                        False
# 2926                         False                        False
# 2927                         False                        False
# 2928                         False                        False
# 2929                         False                        False
#
#       Neighborhood_Qual_Somerst_6  Neighborhood_Qual_Somerst_7  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Somerst_8  Neighborhood_Qual_Somerst_9  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_StoneBr_10  Neighborhood_Qual_StoneBr_7  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ...                            ...                          ...
# 2925                         False                        False
# 2926                         False                        False
# 2927                         False                        False
# 2928                         False                        False
# 2929                         False                        False
#
#       Neighborhood_Qual_StoneBr_8  Neighborhood_Qual_StoneBr_9  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Timber_10  Neighborhood_Qual_Timber_5  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 2925                        False                       False
# 2926                        False                       False
# 2927                        False                       False
# 2928                        False                       False
# 2929                        False                       False
#
#       Neighborhood_Qual_Timber_6  Neighborhood_Qual_Timber_7  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_Timber_8  Neighborhood_Qual_Timber_9  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 2925                       False                       False
# 2926                       False                       False
# 2927                       False                       False
# 2928                       False                       False
# 2929                       False                       False
#
#       Neighborhood_Qual_Veenker_5  Neighborhood_Qual_Veenker_6  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Veenker_7  Neighborhood_Qual_Veenker_8  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2925                        False                        False
# 2926                        False                        False
# 2927                        False                        False
# 2928                        False                        False
# 2929                        False                        False
#
#       Neighborhood_Qual_Veenker_9
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 2925                        False
# 2926                        False
# 2927                        False
# 2928                        False
# 2929                        False
#
# [2930 rows x 154 columns]

# %%
#Dropping features with low correlation
data_encoded = data_encoded.loc[:, ~data_selected.columns.isin(['Mo Sold', 'Yr Sold'])]
data_encoded
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[113], line 2
#       1 #Dropping features with low correlation
# ----> 2 data_encoded = data_encoded.loc[:, ~data_selected.columns.isin(['Mo Sold', 'Yr Sold'])]
#       3 data_encoded
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:1209, in _LocationIndexer._getbool_axis(self, key, axis)
#    1205 @final
#    1206 def _getbool_axis(self, key, axis: AxisInt):
#    1207     # caller is responsible for ensuring non-None axis
#    1208     labels = self.obj._get_axis(axis)
# -> 1209     key = check_bool_indexer(labels, key)
#    1210     inds = key.nonzero()[0]
#    1211     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py:2681, in check_bool_indexer(index, key)
#    2677 elif not is_array_like(result):
#    2678     # GH 33924
#    2679     # key may contain nan elements, check_array_indexer needs bool array
#    2680     result = pd_array(result, dtype=bool)
# -> 2681 return check_array_indexer(index, result)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexers\utils.py:539, in check_array_indexer(array, indexer)
#     537     # GH26658
#     538     if len(indexer) != len(array):
# --> 539         raise IndexError(
#     540             f"Boolean index has wrong length: "
#     541             f"{len(indexer)} instead of {len(array)}"
#     542         )
#     543 elif is_integer_dtype(dtype):
#     544     try:
#
# IndexError: Boolean index has wrong length: 19 instead of 154
